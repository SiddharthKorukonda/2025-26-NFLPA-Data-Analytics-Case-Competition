# %%
from pathlib import Path
import duckdb

DB_DIR = Path("../db")
DB_DIR.mkdir(parents=True, exist_ok=True)

con = duckdb.connect(str(DB_DIR / "nflpa.duckdb"))

print("db file", (DB_DIR / "nflpa.duckdb").resolve())
# Out:
# db file /Users/ramko/Desktop/2025-26-NFLPA-Data-Analytics-Case-Competition/db/nflpa.duckdb

# %%
con.execute("CREATE OR REPLACE VIEW pbp AS SELECT * FROM read_parquet('../data/raw/pbp.parquet')")
con.execute("CREATE OR REPLACE VIEW schedules AS SELECT * FROM read_parquet('../data/raw/schedules.parquet')")
con.execute("CREATE OR REPLACE VIEW injuries AS SELECT * FROM read_parquet('../data/raw/injuries.parquet')")
con.execute("CREATE OR REPLACE VIEW snap_counts AS SELECT * FROM read_parquet('../data/raw/snap_counts.parquet')")
con.execute("CREATE OR REPLACE VIEW players AS SELECT * FROM read_parquet('../data/raw/players.parquet')")
con.execute("CREATE OR REPLACE VIEW rosters_weekly AS SELECT * FROM read_parquet('../data/raw/rosters_weekly.parquet')")

print("views created")
# Out:
# views created

# %%
for name in ["pbp","schedules","injuries","snap_counts","players"]:
    n = con.execute(f"SELECT COUNT(*) FROM {name}").fetchone()[0]
    print(name, n)
# Out:
# pbp 627226
# schedules 3544
# injuries 70401
# snap_counts 297999
# players 24350

# %% [markdown]
# Quick sanity checks

# %%
con.execute("""
SELECT play_type, COUNT(*) AS n
FROM pbp
WHERE play_type IS NOT NULL
GROUP BY 1
ORDER BY n DESC
LIMIT 50
""").df()
# Out:
#      play_type       n
# 0         pass  262139
# 1          run  184080
# 2      no_play   58822
# 3      kickoff   36301
# 4         punt   30672
# 5  extra_point   16659
# 6   field_goal   13741
# 7     qb_kneel    5464
# 8     qb_spike     924

# %%
con.execute("DESCRIBE injuries").df()
# Out:
#                   column_name               column_type null   key default  \
# 0                      season                    DOUBLE  YES  None    None
# 1                   game_type                   VARCHAR  YES  None    None
# 2                        team                   VARCHAR  YES  None    None
# 3                        week                    DOUBLE  YES  None    None
# 4                     gsis_id                   VARCHAR  YES  None    None
# 5                    position                   VARCHAR  YES  None    None
# 6                   full_name                   VARCHAR  YES  None    None
# 7                  first_name                   VARCHAR  YES  None    None
# 8                   last_name                   VARCHAR  YES  None    None
# 9       report_primary_injury                   VARCHAR  YES  None    None
# 10    report_secondary_injury                   VARCHAR  YES  None    None
# 11              report_status                   VARCHAR  YES  None    None
# 12    practice_primary_injury                   VARCHAR  YES  None    None
# 13  practice_secondary_injury                   VARCHAR  YES  None    None
# 14            practice_status                   VARCHAR  YES  None    None
# 15              date_modified  TIMESTAMP WITH TIME ZONE  YES  None    None
#
#    extra
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None

# %%
con.execute("""
SELECT season, week, team, COUNT(*) AS rows
FROM injuries
GROUP BY 1,2,3
ORDER BY season DESC, week DESC
LIMIT 20
""").df()
# Out:
#     season  week team  rows
# 0   2024.0  22.0   KC     4
# 1   2024.0  22.0  PHI    11
# 2   2024.0  21.0   KC     4
# 3   2024.0  21.0  WAS    18
# 4   2024.0  21.0  PHI    11
# 5   2024.0  21.0  BUF    12
# 6   2024.0  20.0   LA     7
# 7   2024.0  20.0  DET     6
# 8   2024.0  20.0  BUF    12
# 9   2024.0  20.0  HOU    11
# 10  2024.0  20.0   KC    11
# 11  2024.0  20.0  BAL     2
# 12  2024.0  20.0  WAS    17
# 13  2024.0  20.0  PHI     8
# 14  2024.0  19.0  HOU    11
# 15  2024.0  19.0  PIT    10
# 16  2024.0  19.0  BAL     4
# 17  2024.0  19.0  BUF    16
# 18  2024.0  19.0   TB    17
# 19  2024.0  19.0   GB    12

# %%
con.execute("""
SELECT season, week, game_id, home_team, away_team
FROM schedules
ORDER BY season DESC, week DESC
LIMIT 10
""").df()
# Out:
#    season  week          game_id home_team away_team
# 0    2024    22   2024_22_KC_PHI       PHI        KC
# 1    2024    21  2024_21_WAS_PHI       PHI       WAS
# 2    2024    21   2024_21_BUF_KC        KC       BUF
# 3    2024    20   2024_20_HOU_KC        KC       HOU
# 4    2024    20  2024_20_WAS_DET       DET       WAS
# 5    2024    20   2024_20_LA_PHI       PHI        LA
# 6    2024    20  2024_20_BAL_BUF       BUF       BAL
# 7    2024    19  2024_19_PIT_BAL       BAL       PIT
# 8    2024    19   2024_19_GB_PHI       PHI        GB
# 9    2024    19   2024_19_MIN_LA        LA       MIN

# %%
con.execute("DESCRIBE rosters_weekly").df()
# Out:
#                 column_name column_type null   key default extra
# 0                    season     INTEGER  YES  None    None  None
# 1                      team     VARCHAR  YES  None    None  None
# 2                  position     VARCHAR  YES  None    None  None
# 3      depth_chart_position     VARCHAR  YES  None    None  None
# 4             jersey_number     VARCHAR  YES  None    None  None
# 5                    status     VARCHAR  YES  None    None  None
# 6                 full_name     VARCHAR  YES  None    None  None
# 7                first_name     VARCHAR  YES  None    None  None
# 8                 last_name     VARCHAR  YES  None    None  None
# 9                birth_date        DATE  YES  None    None  None
# 10                   height      DOUBLE  YES  None    None  None
# 11                   weight     INTEGER  YES  None    None  None
# 12                  college     VARCHAR  YES  None    None  None
# 13                  gsis_id     VARCHAR  YES  None    None  None
# 14                  espn_id     VARCHAR  YES  None    None  None
# 15            sportradar_id     VARCHAR  YES  None    None  None
# 16                 yahoo_id     VARCHAR  YES  None    None  None
# 17              rotowire_id     VARCHAR  YES  None    None  None
# 18                   pff_id     VARCHAR  YES  None    None  None
# 19                   pfr_id     VARCHAR  YES  None    None  None
# 20          fantasy_data_id     VARCHAR  YES  None    None  None
# 21               sleeper_id     VARCHAR  YES  None    None  None
# 22                years_exp     INTEGER  YES  None    None  None
# 23             headshot_url     VARCHAR  YES  None    None  None
# 24             ngs_position     VARCHAR  YES  None    None  None
# 25                     week     INTEGER  YES  None    None  None
# 26                game_type     VARCHAR  YES  None    None  None
# 27  status_description_abbr     VARCHAR  YES  None    None  None
# 28            football_name     VARCHAR  YES  None    None  None
# 29                   esb_id     VARCHAR  YES  None    None  None
# 30               gsis_it_id     VARCHAR  YES  None    None  None
# 31                 smart_id     VARCHAR  YES  None    None  None
# 32               entry_year     INTEGER  YES  None    None  None
# 33              rookie_year     INTEGER  YES  None    None  None
# 34               draft_club     VARCHAR  YES  None    None  None
# 35             draft_number     VARCHAR  YES  None    None  None
