# %%
from pathlib import Path
import nflreadpy as nfl

DATA_DIR = Path("../data/raw")
DATA_DIR.mkdir(parents=True, exist_ok=True)

seasons = list(range(2012, 2025))

# %%
from nflreadpy.config import update_config

update_config(
    cache_mode="filesystem",
    cache_dir=Path("../.nflreadpy_cache"),
    cache_duration=86400,
    verbose=True,
)

# %%
pbp = nfl.load_pbp(seasons)
schedules = nfl.load_schedules(seasons)
injuries = nfl.load_injuries(seasons)
snap_counts = nfl.load_snap_counts(seasons)
players = nfl.load_players()
rosters_weekly = nfl.load_rosters_weekly(seasons)
# Out:
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2012.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.3M/19.3M [00:05<00:00, 3.29MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2013.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.5M/19.5M [00:06<00:00, 3.21MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2014.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.4M/19.4M [00:06<00:00, 2.99MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2015.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.5M/19.5M [00:06<00:00, 3.04MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2016.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.3M/19.3M [00:07<00:00, 2.75MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2017.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.1M/19.1M [00:06<00:00, 3.08MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2018.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.1M/19.1M [00:06<00:00, 3.14MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2019.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.1M/19.1M [00:05<00:00, 3.27MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2020.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 19.3M/19.3M [00:06<00:00, 2.95MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2021.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 20.3M/20.3M [00:06<00:00, 3.10MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2022.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 20.4M/20.4M [00:06<00:00, 3.03MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2023.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 20.5M/20.5M [00:06<00:00, 3.02MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2024.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 20.6M/20.6M [00:07<00:00, 2.71MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/schedules/games.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 506k/506k [00:00<00:00, 6.88MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2012.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 120k/120k [00:00<00:00, 5.38MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2013.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 114k/114k [00:00<00:00, 9.47MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2014.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 115k/115k [00:00<00:00, 7.44MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2015.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 118k/118k [00:00<00:00, 6.57MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2016.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 112k/112k [00:00<00:00, 13.1MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2017.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 115k/115k [00:00<00:00, 8.70MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2018.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 114k/114k [00:00<00:00, 4.67MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2019.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 119k/119k [00:00<00:00, 15.2MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2020.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 125k/125k [00:00<00:00, 6.95MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2021.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 126k/126k [00:00<00:00, 9.33MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2022.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 130k/130k [00:00<00:00, 11.6MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2023.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 127k/127k [00:00<00:00, 19.2MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2024.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 139k/139k [00:00<00:00, 16.2MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2012.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 4.56k/4.56k [00:00<00:00, 13.4MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2013.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 210k/210k [00:00<00:00, 4.79MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2014.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 212k/212k [00:00<00:00, 7.98MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2015.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 212k/212k [00:00<00:00, 12.4MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2016.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 212k/212k [00:00<00:00, 6.74MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2017.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 212k/212k [00:00<00:00, 7.66MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2018.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 212k/212k [00:00<00:00, 8.34MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2019.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 213k/213k [00:00<00:00, 10.4MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2020.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 232k/232k [00:00<00:00, 5.66MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2021.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 241k/241k [00:00<00:00, 5.26MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2022.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 238k/238k [00:00<00:00, 9.28MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2023.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 238k/238k [00:00<00:00, 4.02MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/snap_counts/snap_counts_2024.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 241k/241k [00:00<00:00, 7.16MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/players/players.parquet
# Downloading: 100%|███████████████████████████████████████████████████████████| 3.31M/3.31M [00:00<00:00, 4.87MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2012.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 444k/444k [00:00<00:00, 5.00MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2013.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 462k/462k [00:00<00:00, 5.34MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2014.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 489k/489k [00:00<00:00, 9.37MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2015.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 512k/512k [00:00<00:00, 5.43MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2016.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 754k/754k [00:00<00:00, 8.45MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2017.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 735k/735k [00:00<00:00, 7.20MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2018.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 763k/763k [00:00<00:00, 3.65MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2019.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 779k/779k [00:00<00:00, 5.55MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2020.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 844k/844k [00:00<00:00, 7.83MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2021.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 817k/817k [00:00<00:00, 7.77MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2022.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 804k/804k [00:00<00:00, 4.41MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2023.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 794k/794k [00:00<00:00, 6.69MB/s]
# Downloading https://github.com/nflverse/nflverse-data/releases/download/weekly_rosters/roster_weekly_2024.parquet
# Downloading: 100%|█████████████████████████████████████████████████████████████| 829k/829k [00:00<00:00, 7.29MB/s]

# %%
pbp.write_parquet(DATA_DIR / "pbp.parquet")
schedules.write_parquet(DATA_DIR / "schedules.parquet")
injuries.write_parquet(DATA_DIR / "injuries.parquet")
snap_counts.write_parquet(DATA_DIR / "snap_counts.parquet")
players.write_parquet(DATA_DIR / "players.parquet")
rosters_weekly.write_parquet(DATA_DIR / "rosters_weekly.parquet")

print("download complete")
# Out:
# download complete

# %%
files = [
    "pbp.parquet",
    "schedules.parquet",
    "injuries.parquet",
    "snap_counts.parquet",
    "players.parquet",
    "rosters_weekly.parquet",
]

for f in files:
    p = DATA_DIR / f
    print(f, p.exists(), p.stat().st_size if p.exists() else None)
# Out:
# pbp.parquet True 168542229
# schedules.parquet True 180361
# injuries.parquet True 982163
# snap_counts.parquet True 2569972
# players.parquet True 2100805
# rosters_weekly.parquet True 4434832

# %%
print("pbp", pbp.shape)
print("schedules", schedules.shape)
print("injuries", injuries.shape)
print("snap_counts", snap_counts.shape)
print("players", players.shape)
print("rosters_weekly", rosters_weekly.shape)
# Out:
# pbp (627226, 372)
# schedules (3544, 46)
# injuries (70401, 16)
# snap_counts (297999, 16)
# players (24350, 39)
# rosters_weekly (546828, 36)
